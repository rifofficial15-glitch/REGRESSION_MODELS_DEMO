# %%
# !pip install scikit-learn

import pandas as pd
df = pd.read_csv("D:\\Datasets\\Housing.csv")

df.head(10)
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
# ...

# %%
df.tail(10)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 535  2100000  3360         2          1        1      yes        no       no
# 536  1960000  3420         5          1        2       no        no       no
# 537  1890000  1700         3          1        2      yes        no       no
# 538  1890000  3649         2          1        1      yes        no       no
# 539  1855000  2990         2          1        1       no        no       no
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
# TO FIND THE STATISTICAL INFO.
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# TO FIND NULL OBJECTS & DATATYPES
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    str
#  6   guestroom         545 non-null    str
#  7   basement          545 non-null    str
#  8   hotwaterheating   545 non-null    str
#  9   airconditioning   545 non-null    str
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    str
#  12  furnishingstatus  545 non-null    str
# dtypes: int64(6), str(7)
# memory usage: 55.5 KB

# %%
df.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.nunique()
# Out:
# price               219
# area                284
# bedrooms              6
# bathrooms             4
# stories               4
# mainroad              2
# guestroom             2
# basement              2
# hotwaterheating       2
# airconditioning       2
# parking               4
# prefarea              2
# furnishingstatus      3
# dtype: int64

# %% [markdown]
# IN OUR DATASET,
# PRICE --->  OUTPUT(predict)
# OTHERS ---> INPUT
#
# READ THE DATASET FOR 'OBJECT VALUES SUCH AS YES / NO'..
# AND THESE COLUMNS SHOULD BE PREPROCESSED..
#
# IN PREPROCESSING, WE ARE GOING TO REPLACE YES = 1 ; NO = 0..

# %%
List_1 = ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']
df[List_1] = df[List_1].replace({'yes':1, 'no':0})
df.head(5)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3        1         0        0
# 1  12250000  8960         4          4        4        1         0        0
# 2  12250000  9960         3          2        2        1         0        1
# 3  12215000  7500         4          2        2        1         0        1
# 4  11410000  7420         4          1        2        1         1        1
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0               0               1        2        1        furnished
# 1               0               1        3        0        furnished
# 2               0               0        2        1   semi-furnished
# 3               0               1        3        1        furnished
# 4               0               1        2        0        furnished

# %%
# IN THE FURNISHINGSTATUS COLUMN WE HAVE 'UNIQUE VALUES'

df['furnishingstatus'].nunique()
# Out:
# 3

# %%
df['furnishingstatus'] = df['furnishingstatus'].replace({'unfurnished':0, 'semi-furnished':1, 'furnished':2})
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3        1         0        0
# 1  12250000  8960         4          4        4        1         0        0
# 2  12250000  9960         3          2        2        1         0        1
# 3  12215000  7500         4          2        2        1         0        1
# 4  11410000  7420         4          1        2        1         1        1
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0               0               1        2        1                2
# 1               0               1        3        0                2
# 2               0               0        2        1                1
# 3               0               1        3        1                2
# 4               0               1        2        0                2

# %%
#WE CANNOT GET PATTERNS EASILY IF THE NUMBERS ARE IN '1000' OR LAKHS OR MILLIONS..
#SO WE USE STANDARDISATION TECHNIQUE TO SCALE IT..

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
List_2 = ['price', 'area']

df[List_2] = scaler.fit_transform(df[List_2])
df.head(10)
# Out:
#       price      area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0  4.566365  1.046726         4          2        3        1         0
# 1  4.004484  1.757010         4          4        4        1         0
# 2  4.004484  2.218232         3          2        2        1         0
# 3  3.985755  1.083624         4          2        2        1         0
# 4  3.554979  1.046726         4          1        2        1         1
# 5  3.255309  1.083624         3          3        1        1         0
# 6  2.880722  1.581745         4          3        4        1         0
# 7  2.880722  5.096263         5          3        2        1         0
# 8  2.730887  1.360358         4          1        2        1         1
# 9  2.693428  0.276484         3          2        4        1         1
#
#   basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0        0               0               1        2        1                2
# ...

# %% [markdown]
# NOW THE PRICE & AREA WILL BE CONVERTED TO FLOAT VALUES..
#
# SO, ALL OBJECTS ARE CONVERTED TO INT OR FLOAT..

# %% [markdown]
# NOW DATA VISUALIZATION.....

# %%
# TO IDENTIFY DATA STRUCTURE..

corr = df.corr()

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (10,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# CORRELATION MATRIX IS VISIBLE IN HEATMAP.
# PRICE (OUTPUT) & OTHERS (INPUT) CORRELATION IS NEEDED..
#
# IF VALUE > 0.5 AND < -0.5, THEN THOSE COLUMNS ARE CONSIDERED..
#
# THE MACHINE LEARNING (ML) MODEL GIVES ACCURACY FOR THIS CONSIDERATIONS..

# %%
# NOW DISTRIBUTION CONCEPT IN PROBABILITY IS USED..
df.hist(figsize = (10,10), bins = 10)
plt.show()

# %% [markdown]
# IT SHOWS COLUMN VALUES IN DIFFERENT DISTRIBUTIONS..
#
# OUR WORK IS TO MAKE THEM INTO NORMAL DISTRIBUTION..

# %%
# MODEL TRAINING

# NOW WE HAVE TO TAKE INPUT COLUMNS IN ONE VARIABLE & OUTPUT COLUMN IN ANOTHER VARIABLE

x = df.drop('price', axis = 1)
y = df['price']

# %% [markdown]
# HERE WE ARE GETTING ALL COLUMNS EXCEPT 'PRICE' COLUMN AS INPUT..
#
#  AXIS = 1 MEANS DROP THE WHOLE COLUMN..
#
#  AXIS = 2 MEANS DROP THE FIRST ROW..

# %%
x
# Out:
#          area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    1.046726         4          2        3        1         0        0
# 1    1.757010         4          4        4        1         0        0
# 2    2.218232         3          2        2        1         0        1
# 3    1.083624         4          2        2        1         0        1
# 4    1.046726         4          1        2        1         1        1
# ..        ...       ...        ...      ...      ...       ...      ...
# 540 -0.991879         2          1        1        1         0        1
# 541 -1.268613         3          1        1        0         0        0
# 542 -0.705921         2          1        1        1         0        0
# 543 -1.033389         3          1        1        0         0        0
# 544 -0.599839         3          1        2        1         0        0
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
y
# Out:
# 0      4.566365
# 1      4.004484
# 2      4.004484
# 3      3.985755
# 4      3.554979
#          ...
# 540   -1.576868
# 541   -1.605149
# 542   -1.614327
# 543   -1.614327
# 544   -1.614327
# Name: price, Length: 545, dtype: float64

# %% [markdown]
# NOW WE ARE GOING TO USE LINEAR REGRESSION..
#
# BEFORE THAT WE HAVE TO SEPARATE THE DATASET FOR 'TRAINING' & 'TESTING'

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"'x_train {x_train.shape}")

print(f"'x_test {x_test.shape}")
# Out:
# 'x_train (436, 12)
# 'x_test (109, 12)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression() # loading model into variable

lr.fit(x_train, y_train)  # fitting variable to our dataset
# Out:
# LinearRegression()

# %% [markdown]
# WE HAVE TRAINED OUR MODEL, NOW WE HAVE TO PREDICT THE VALUES

# %%
y_predict = lr.predict(x_test)

# %%
# TO FIND ITE ACCURACY, WE USE METRICS..

from sklearn.metrics import r2_score

lr_accuracy = r2_score(y_test, y_predict) * 100

# %%
# THE DIFFERENCEC BETWEEN OUR ACTUAL DATA & PREDICT DATA WILL GIVE THE ERROR..

lr_accuracy
# Out:
# 64.94754192267796

# %% [markdown]
# NOW I WANT TO TEST AND TRAIN THE DATASET USING ALL THE REGRESSION MODELS...

# %%
# WE NEED TO REMOVE THE OUTLIERS..
"""import numpy as np
import seaborn as sns
import scipy.stats as stats

numeric_df = df.select_dftypes(include=[np.number])

z_scores = stats.zscore(df)
threshold = 3
print("SIZE BEFORE REMOVING OUTLIERS: ", df.shape)

# Z_SCORES > THRESHOLD ARE OUTLIERS 
outliers_df = df[(z_scores>threshold).any(axis=1)]

#Z_SCORES <= THRESHOLD ARE TO BE IN MY DATASETS..
df = df[(z_scores <= threshold).all(axis=1)]

print("SIZE AFTER REMOVING OUTLIERS: ", df.shape)

# I GOT ERRORS................................
# Out:
#   Cell In[21], line 2
#     """import numpy as np
#     ^
# _IncompleteInputError: incomplete input

# %%
df.head(5)
# Out:
#       price      area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0  4.566365  1.046726         4          2        3        1         0
# 1  4.004484  1.757010         4          4        4        1         0
# 2  4.004484  2.218232         3          2        2        1         0
# 3  3.985755  1.083624         4          2        2        1         0
# 4  3.554979  1.046726         4          1        2        1         1
#
#   basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0        0               0               1        2        1                2
# 1        0               0               1        3        0                2
# 2        1               0               0        2        1                1
# 3        1               0               1        3        1                2
# 4        1               0               1        2        0                2

# %%
df.dtypes
print(df.select_dtypes(include='object').columns)
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea', 'furnishingstatus'],
#       dtype='str')

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
print(df.isna().sum())
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
# WE NEED TO REMOVE THE OUTLIERS..
import numpy as np
import seaborn as sns
import scipy.stats as stats

z_scores = stats.zscore(df)
threshold = 3
print("SIZE BEFORE REMOVING OUTLIERS: ", df.shape)

# Z_SCORES > THRESHOLD ARE OUTLIERS 
outliers_df = df[(z_scores>threshold).any(axis=1)]

#Z_SCORES <= THRESHOLD ARE TO BE IN MY DATASETS..
df = df[(z_scores <= threshold).all(axis=1)]

print("SIZE AFTER REMOVING OUTLIERS: ", df.shape)
# Out:
# SIZE BEFORE REMOVING OUTLIERS:  (545, 13)
# SIZE AFTER REMOVING OUTLIERS:  (499, 13)

# %%
outliers_df.head()
# Out:
#       price      area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  4.566365  1.046726         4          2        3         1          0
# 1  4.004484  1.757010         4          4        4         1          0
# 2  4.004484  2.218232         3          2        2         1          0
# 3  3.985755  1.083624         4          2        2         1          0
# 4  3.554979  1.046726         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 2
# 1                 2
# 2                 1
# 3                 2
# 4                 2

# %%
# IN ORDER TO STANDARDISE MY DATA INTO SAME UNIT SCALE..

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(df)

df_scaled = pd.DataFrame(scaler.transform(df), columns=df.columns)

# %%
# MODEL TRAINING

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# NOW WE HAVE TO TAKE INPUT COLUMNS IN ONE VARIABLE & OUTPUT COLUMN IN ANOTHER VARIABLE

x = df.drop("price", axis = 1)
y = df["price"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42) # we are giving 25% in my test dataset..

print(f"'x_train {x_train.shape}")

print(f"'x_test {x_test.shape}")
# Out:
# 'x_train (399, 12)
# 'x_test (100, 12)

# %%
models = [
    ('Random Forest', RandomForestRegressor()),
    ('Linear Regression', LinearRegression()),
    ('Decision Tree', DecisionTreeRegressor()),
    ('KNN', KNeighborsRegressor())
]

# %% [markdown]
# NOW I AM GOING TO TRAIN THE MODELS BY GIVING DATA AND THEN I'LL TEST THEM

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
for name, model in models:
    print(name)
    print()
    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    print("MEAN SQUARED ERROR:", mean_squared_error(y_test, y_pred))
    print('\n')
    print("MEAN ABSOLUTE ERROR [MAE]:", mean_absolute_error(y_test, y_pred))
    print('\n')
    print("R-SQUARED (R2) ", r2_score(y_test, y_pred))
    print('\n')
# Out:
# Random Forest
#
# MEAN SQUARED ERROR: 0.3470834152354112
#
#
# MEAN ABSOLUTE ERROR [MAE]: 0.4432294585717866
#
#
# R-SQUARED (R2)  0.6305776786397721
#
#
# Linear Regression
#
# MEAN SQUARED ERROR: 0.3132219189381797
#
#
# MEAN ABSOLUTE ERROR [MAE]: 0.4116229063762947
#
#
# R-SQUARED (R2)  0.6666185610840387
#
#
# Decision Tree
#
# MEAN SQUARED ERROR: 0.4920580444220046
#
#
# MEAN ABSOLUTE ERROR [MAE]: 0.515151303076182
#
#
# R-SQUARED (R2)  0.47627222438427474
#
#
# KNN
#
# MEAN SQUARED ERROR: 0.3312010699663974
#
#
# MEAN ABSOLUTE ERROR [MAE]: 0.4389870491496995
#
#
# R-SQUARED (R2)  0.6474822399076858

# %% [markdown]
# BASED ON THE NUMBERS,
#
# LINEAR REGRESSION IS OUR BEST MODEL.
#
# MSE: 0.3132 --> LOWEST
#
# MAE: 0.4116 --> LOWEST
#
# R2: 0.6666 --> HIGHEST

# %% [markdown]
# "AMONG THE FOUR MODELS TESTED,
# LINEAR REGRESSION PERFORMED THE BEST,
# ACHIEVING AN R2 SCORE OF APPROXIMATELY 0.667, WITH THE LOWEST MSE & MAE.."
